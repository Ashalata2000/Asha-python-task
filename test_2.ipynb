# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashalata2000/Asha-python-task/blob/main/test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = ["Rahul", "Anita", "Siva", "Priya", "Kiran"]

print("Student Names:")
for name in students:
    print(name)
# Out:
# Student Names:
# Rahul
# Anita
# Siva
# Priya
# Kiran

# %%
numbers = [10, 20, 30, 40, 50]

print("First Element:", numbers[0])
print("Last Element:", numbers[-1])
# Out:
# First Element: 10
# Last Element: 50

# %%
fruits = ["Apple", "Banana", "Mango"]

fruits.append("Orange")

print("Updated List:", fruits)
# Out:
# Updated List: ['Apple', 'Banana', 'Mango', 'Orange']

# %%
subjects = ["Math", "Science", "English", "History"]

subjects.insert(2, "AI")

print("Updated Subjects:", subjects)
# Out:
# Updated Subjects: ['Math', 'Science', 'AI', 'English', 'History']

# %%
numbers = [10, 20, 30, 40, 50]

numbers.pop(2)

print("Updated List:", numbers)
# Out:
# Updated List: [10, 20, 40, 50]

# %%
numbers = [10, 20, 30, 40, 50]

print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Sum:", sum(numbers))
# Out:
# Length: 5
# Maximum: 50
# Minimum: 10
# Sum: 150

# %%
numbers = []

for i in range(5):
    num = int(input("Enter a number: ")) # Assign input to a new variable 'num'
    numbers.append(num) # Append 'num' to the 'numbers' list

print("Complete List:", numbers)
# Out:
# Enter a number: 5
# Enter a number: 6
# Enter a number: 1
# Enter a number: 9
# Enter a number: 7
# Complete List: [5, 6, 1, 9, 7]

# %%
cities = ["Delhi", "Mumbai", "Chennai", "Hyderabad"]

if "Delhi" in cities:
    print("Delhi exists in the list.")
else:
    print("Delhi does not exist in the list.")
# Out:
# Delhi exists in the list.

# %%
colors = ("Red", "Blue", "Green", "Yellow", "Black")

print("Colors:")
for color in colors:
    print(color)
# Out:
# Colors:
# Red
# Blue
# Green
# Yellow
# Black

# %%
numbers = (10, 20, 30, 40, 50)

print("First Element:", numbers[0])
print("Last Element:", numbers[-1])
# Out:
# First Element: 10
# Last Element: 50

# %%
students = ("Siva", "Anita", "Siva", "Rahul", "Siva")

name = input("Enter name to count: ")

print("Occurrences:", students.count(name))
# Out:
# Enter name to count: Siva
# Occurrences: 3

# %%
numbers = (15, 25, 35, 45, 55)

print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Length:", len(numbers))
# Out:
# Maximum: 55
# Minimum: 15
# Length: 5

# %%
# Original code (produces TypeError):
# t = (10, 20, 30)
# t[1] = 50

# To modify elements, use a list instead:
my_list = [10, 20, 30]
my_list[1] = 50
print("Modified List:", my_list)

# If you specifically need a tuple after modification, convert it back:
modified_tuple = tuple(my_list)
print("Modified Tuple:", modified_tuple)
# Out:
# Modified List: [10, 50, 30]
# Modified Tuple: (10, 50, 30)

# %%
t = (1, 2, 3, 4, 5)

lst = list(t)

print("List:", lst)
# Out:
# List: [1, 2, 3, 4, 5]

# %%
s = {10, 20, 30, 40, 50}

print("Set:", s)
# Out:
# Set: {50, 20, 40, 10, 30}

# %%
s = {10, 20, 30}

s.add(40)

print("Updated Set:", s)
# Out:
# Updated Set: {40, 10, 20, 30}

# %%
s = {10, 20, 30, 40}

s.remove(20)

print("Updated Set:", s)
# Out:
# Updated Set: {40, 10, 30}

# %%
s = {10, 20, 30, 30, 40, 40}

print("Set:", s)
# Out:
# Set: {40, 10, 20, 30}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

print("Union:", A.union(B))
print("Intersection:", A.intersection(B))
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}

# %%
s = {10, 20, 30, 40, 50}

num = int(input("Enter a number: "))

if num in s:
    print("Number exists in the set.")
else:
    print("Number does not exist in the set.")
# Out:
# Enter a number: 6
# Number does not exist in the set.

# %%
person = {
    "name": "Rahul",
    "age": 22,
    "city": "Delhi"
}

print("Values:")
for value in person.values():
    print(value)
# Out:
# Values:
# Rahul
# 22
# Delhi

# %%
student = {
    "name": "Siva",
    "age": 24
}

student["course"] = "Python"

print(student)
# Out:
# {'name': 'Siva', 'age': 24, 'course': 'Python'}

# %%
employee = {
    "ID": 101,
    "Name": "John",
    "Salary": 50000
}

print("Keys:", employee.keys())
print("Values:", employee.values())
# Out:
# Keys: dict_keys(['ID', 'Name', 'Salary'])
# Values: dict_values([101, 'John', 50000])

# %%
student = {
    "name": "Rahul",
    "age": 20
}

student["age"] = 21

print(student)
# Out:
# {'name': 'Rahul', 'age': 21}

# %%
person = {
    "name": "Test",
    "age": 24,
    "city": "Chennai"
}

person.pop("city")

print(person)
# Out:
# {'name': 'Test', 'age': 24}

# %%
marks = {
    "Rahul": 80,
    "Priya": 90,
    "Amit": 75,
    "Sneha": 95,
    "Kiran": 88
}

print("Student Names:")

for name in marks.keys():
    print(name)
# Out:
# Student Names:
# Rahul
# Priya
# Amit
# Sneha
# Kiran

# %%
products = {
    "Laptop": 50000,
    "Mouse": 500,
    "Keyboard": 1200
}

item = input("Enter product name: ")

if item in products:
    print("Price:", products[item])
else:
    print("Product not found.")
# Out:
# Enter product name: Mouse
# Price: 500

# %%
student = {
    "name": "Rahul",
    "age": 20
}

key = input("Enter key: ")

if key in student:
    print("Key exists.")
else:
    print("Key does not exist.")
# Out:
# Enter key: adress
# Key does not exist.

# %%
students = ["Rahul", "Priya", "Amit", "Sneha", "Kiran"]

t = tuple(students)

print(t)
# Out:
# ('Rahul', 'Priya', 'Amit', 'Sneha', 'Kiran')

# %%
marks = {
    "Rahul": 85,
    "Priya": 92,
    "Amit": 76,
    "Sneha": 88,
    "Kiran": 70
}

print("Students scoring more than 80:")

for student, mark in marks.items():
    if mark > 80:
        print(student, ":", mark)
# Out:
# Students scoring more than 80:
# Rahul : 85
# Priya : 92
# Sneha : 88
